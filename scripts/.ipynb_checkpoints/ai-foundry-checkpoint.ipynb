# %% [markdown]
# # Uploading documents

# %%
from azure.identity import DefaultAzureCredential
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
from dotenv import load_dotenv
import os

load_dotenv()  # Automatically loads variables from .env file
# Out:
# True

# %%
# === 1. KONFIGURATION ===
storage_account_url = "https://team5storage.blob.core.windows.net"
container_name = "elternleben_de"
local_folder_path = "../../../n3xtcoder/ai4impact-elternleben"

# %%
# === 2. VERBINDUNG AUFBAUEN ===
credential = DefaultAzureCredential()
print credential;
blob_service_client = BlobServiceClient(account_url=storage_account_url, credential=credential)

# %%
# === 3. CONTAINER ERSTELLEN (falls nicht vorhanden) ===
try:
    container_client = blob_service_client.create_container(container_name)
    print(f"Container '{container_name}' wurde erstellt.")
except Exception as e:
    print(f"Container '{container_name}' existiert wahrscheinlich schon. {e}")
    container_client = blob_service_client.get_container_client(container_name)
# Out:
# Exception in thread Thread-82 (_readerthread):
# Traceback (most recent call last):
#   File "C:\Users\tg\AppData\Local\Programs\Python\Python313\Lib\threading.py", line 1041, in _bootstrap_inner
#     self.run()
#     ~~~~~~~~^^
#   File "C:\Users\tg\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel\ipkernel.py", line 766, in run_closure
#     _threading_Thread_run(self)
#     ~~~~~~~~~~~~~~~~~~~~~^^^^^^
#   File "C:\Users\tg\AppData\Local\Programs\Python\Python313\Lib\threading.py", line 992, in run
#     self._target(*self._args, **self._kwargs)
#     ~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\tg\AppData\Local\Programs\Python\Python313\Lib\subprocess.py", line 1612, in _readerthread
#     buffer.append(fh.read())
#                   ~~~~~~~^^
#   File "C:\Users\tg\AppData\Local\Programs\Python\Python313\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 271: character maps to <undefined>
# AzureDeveloperCliCredential.get_token_info failed: {"type":"consoleMessage","timestamp":"2025-04-28T17:22:05.5424797+02:00","data":{"message":"\nERROR: fetching token: AADSTS50020: User account '{EUII Hidden}' from identity provider 'https://sts.windows.net/ff9527af-b2c8-4690-8d43-bb9d700dc274/' does not exist in tenant 'Microsoft' and cannot access the application '04b07795-8ddb-461a-bbee-02f9e1bf7b46'(Microsoft Azure CLI) in that tenant. The account needs to be added as an external user in the tenant first. Sign out and sign in again with a different Azure Active Directory user account. Trace ID: 75fd4917-6da7-41c3-9b15-566ab0aa2c00 Correlation ID: 9fe69bbc-71c8-4401-8401-e9016b612aef Timestamp: 2025-04-28 15:22:04Z\n"}}
# {"type":"consoleMessage","timestamp":"2025-04-28T17:22:05.5879277+02:00","data":{"message":"Suggestion: reauthentication required, run `azd auth login --scope https://storage.azure.com/.default` to acquire a new token.\n"}}
#
# AzureDeveloperCliCredential.get_token_info failed: {"type":"consoleMessage","timestamp":"2025-04-28T17:22:23.7217816+02:00","data":{"message":"\nERROR: fetching token: AADSTS50020: User account '{EUII Hidden}' from identity provider 'https://sts.windows.net/ff9527af-b2c8-4690-8d43-bb9d700dc274/' does not exist in tenant 'Microsoft' and cannot access the application '04b07795-8ddb-461a-bbee-02f9e1bf7b46'(Microsoft Azure CLI) in that tenant. The account needs to be added as an external user in the tenant first. Sign out and sign in again with a different Azure Active Directory user account. Trace ID: 6f72b12b-23dc-47dd-9b1a-1170f8033600 Correlation ID: 8c1e13a0-9fed-4581-8d04-e0ca91aeb0b7 Timestamp: 2025-04-28 15:22:22Z\n"}}
# {"type":"consoleMessage","timestamp":"2025-04-28T17:22:23.7652958+02:00","data":{"message":"Suggestion: reauthentication required, run `azd auth login --scope https://storage.azure.com/.default` to acquire a new token.\n"}}
#
# AzureDeveloperCliCredential.get_token_info failed: {"type":"consoleMessage","timestamp":"2025-04-28T17:22:49.9936777+02:00","data":{"message":"\nERROR: fetching token: AADSTS50020: User account '{EUII Hidden}' from identity provider 'https://sts.windows.net/ff9527af-b2c8-4690-8d43-bb9d700dc274/' does not exist in tenant 'Microsoft' and cannot access the application '04b07795-8ddb-461a-bbee-02f9e1bf7b46'(Microsoft Azure CLI) in that tenant. The account needs to be added as an external user in the tenant first. Sign out and sign in again with a different Azure Active Directory user account. Trace ID: 3553142d-e544-497c-80f2-6c2ab2514600 Correlation ID: eb8d1687-e543-4516-a124-f93d9ee0d6f0 Timestamp: 2025-04-28 15:22:48Z\n"}}
# {"type":"consoleMessage","timestamp":"2025-04-28T17:22:50.0347764+02:00","data":{"message":"Suggestion: reauthentication required, run `azd auth login --scope https://storage.azure.com/.default` to acquire a new token.\n"}}
#
# AzureDeveloperCliCredential.get_token_info failed: {"type":"consoleMessage","timestamp":"2025-04-28T17:23:31.3999481+02:00","data":{"message":"\nERROR: fetching token: AADSTS50020: User account '{EUII Hidden}' from identity provider 'https://sts.windows.net/ff9527af-b2c8-4690-8d43-bb9d700dc274/' does not exist in tenant 'Microsoft' and cannot access the application '04b07795-8ddb-461a-bbee-02f9e1bf7b46'(Microsoft Azure CLI) in that tenant. The account needs to be added as an external user in the tenant first. Sign out and sign in again with a different Azure Active Directory user account. Trace ID: 87914420-f1f5-4ba8-a7cf-39b6d5862700 Correlation ID: 41082ec3-0690-4857-abe0-d2e8f88c7fef Timestamp: 2025-04-28 15:23:30Z\n"}}
# {"type":"consoleMessage","timestamp":"2025-04-28T17:23:31.44255+02:00","data":{"message":"Suggestion: reauthentication required, run `azd auth login --scope https://storage.azure.com/.default` to acquire a new token.\n"}}
# Container 'elternleben_de' existiert wahrscheinlich schon. {"type":"consoleMessage","timestamp":"2025-04-28T17:23:31.3999481+02:00","data":{"message":"\nERROR: fetching token: AADSTS50020: User account '{EUII Hidden}' from identity provider 'https://sts.windows.net/ff9527af-b2c8-4690-8d43-bb9d700dc274/' does not exist in tenant 'Microsoft' and cannot access the application '04b07795-8ddb-461a-bbee-02f9e1bf7b46'(Microsoft Azure CLI) in that tenant. The account needs to be added as an external user in the tenant first. Sign out and sign in again with a different Azure Active Directory user account. Trace ID: 87914420-f1f5-4ba8-a7cf-39b6d5862700 Correlation ID: 41082ec3-0690-4857-abe0-d2e8f88c7fef Timestamp: 2025-04-28 15:23:30Z\n"}}
# {"type":"consoleMessage","timestamp":"2025-04-28T17:23:31.44255+02:00","data":{"message":"Suggestion: reauthentication required, run `azd auth login --scope https://storage.azure.com/.default` to acquire a new token.\n"}}

# %%
# === 4. REKURSIVES HOCHLADEN DER MARKDOWN-DATEIEN ===
for root, dirs, files in os.walk(local_folder_path):
    for filename in files:
        if filename.endswith(".md"):
            file_path_on_disk = os.path.join(root, filename)
            
            # Pfad innerhalb des Containers (ohne lokalen Basisordner)
            relative_path = os.path.relpath(file_path_on_disk, start=local_folder_path)
            blob_client = container_client.get_blob_client(blob=relative_path.replace("\\", "/"))  # Wichtig für Windows
            
            # Datei hochladen
            with open(file_path_on_disk, "rb") as data:
                blob_client.upload_blob(data, overwrite=True)
                print(f"Hochgeladen: {relative_path}")
# Out:
# AzureDeveloperCliCredential.get_token_info failed: {"type":"consoleMessage","timestamp":"2025-04-28T17:20:20.9349608+02:00","data":{"message":"\nERROR: fetching token: AADSTS50020: User account '{EUII Hidden}' from identity provider 'https://sts.windows.net/ff9527af-b2c8-4690-8d43-bb9d700dc274/' does not exist in tenant 'Microsoft' and cannot access the application '04b07795-8ddb-461a-bbee-02f9e1bf7b46'(Microsoft Azure CLI) in that tenant. The account needs to be added as an external user in the tenant first. Sign out and sign in again with a different Azure Active Directory user account. Trace ID: cbcf2cdd-36f5-4ba2-9078-36fd07b24800 Correlation ID: 125c94cf-cb6c-4f80-a06b-5eacf560cd9a Timestamp: 2025-04-28 15:20:19Z\n"}}
# {"type":"consoleMessage","timestamp":"2025-04-28T17:20:20.979799+02:00","data":{"message":"Suggestion: reauthentication required, run `azd auth login --scope https://storage.azure.com/.default` to acquire a new token.\n"}}
#
# AzureDeveloperCliCredential.get_token_info failed: {"type":"consoleMessage","timestamp":"2025-04-28T17:20:38.6896777+02:00","data":{"message":"\nERROR: fetching token: AADSTS50020: User account '{EUII Hidden}' from identity provider 'https://sts.windows.net/ff9527af-b2c8-4690-8d43-bb9d700dc274/' does not exist in tenant 'Microsoft' and cannot access the application '04b07795-8ddb-461a-bbee-02f9e1bf7b46'(Microsoft Azure CLI) in that tenant. The account needs to be added as an external user in the tenant first. Sign out and sign in again with a different Azure Active Directory user account. Trace ID: 9317958d-5501-4064-a9eb-7ef9c0ec4900 Correlation ID: 91567092-a00c-4f18-8d42-05798c8f554b Timestamp: 2025-04-28 15:20:37Z\n"}}
# {"type":"consoleMessage","timestamp":"2025-04-28T17:20:38.7316185+02:00","data":{"message":"Suggestion: reauthentication required, run `azd auth login --scope https://storage.azure.com/.default` to acquire a new token.\n"}}
#
# AzureDeveloperCliCredential.get_token_info failed: {"type":"consoleMessage","timestamp":"2025-04-28T17:21:01.8838019+02:00","data":{"message":"\nERROR: fetching token: AADSTS50020: User account '{EUII Hidden}' from identity provider 'https://sts.windows.net/ff9527af-b2c8-4690-8d43-bb9d700dc274/' does not exist in tenant 'Microsoft' and cannot access the application '04b07795-8ddb-461a-bbee-02f9e1bf7b46'(Microsoft Azure CLI) in that tenant. The account needs to be added as an external user in the tenant first. Sign out and sign in again with a different Azure Active Directory user account. Trace ID: c5955c42-1863-47b5-b10b-6f2a1b504e00 Correlation ID: 62894ce0-a613-4c5b-8fcc-698c5155026b Timestamp: 2025-04-28 15:21:00Z\n"}}
# {"type":"consoleMessage","timestamp":"2025-04-28T17:21:01.9260062+02:00","data":{"message":"Suggestion: reauthentication required, run `azd auth login --scope https://storage.azure.com/.default` to acquire a new token.\n"}}
#
# AzureDeveloperCliCredential.get_token_info failed: {"type":"consoleMessage","timestamp":"2025-04-28T17:21:44.4649893+02:00","data":{"message":"\nERROR: fetching token: AADSTS50020: User account '{EUII Hidden}' from identity provider 'https://sts.windows.net/ff9527af-b2c8-4690-8d43-bb9d700dc274/' does not exist in tenant 'Microsoft' and cannot access the application '04b07795-8ddb-461a-bbee-02f9e1bf7b46'(Microsoft Azure CLI) in that tenant. The account needs to be added as an external user in the tenant first. Sign out and sign in again with a different Azure Active Directory user account. Trace ID: da609b0d-ba24-4e93-b8f5-f52b0cb75b00 Correlation ID: f030ce94-7231-42e4-88a1-6cac30d50234 Timestamp: 2025-04-28 15:21:43Z\n"}}
# {"type":"consoleMessage","timestamp":"2025-04-28T17:21:44.5051876+02:00","data":{"message":"Suggestion: reauthentication required, run `azd auth login --scope https://storage.azure.com/.default` to acquire a new token.\n"}}
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\identity\_credentials\azd_cli.py:264, in _run_command(command_args, timeout)
#     263     _LOGGER.debug("Executing subprocess with the following arguments %s", args)
# --> 264     return subprocess.check_output(args, **kwargs)
#     265 except subprocess.CalledProcessError as ex:
#     266     # non-zero return from shell
#     267     # Fallback check in case the executable is not found while executing subprocess.
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:472, in check_output(timeout, *popenargs, **kwargs)
#     470     kwargs['input'] = empty
# --> 472 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     473            **kwargs).stdout
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\subprocess.py:577, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     576     if check and retcode:
# --> 577         raise CalledProcessError(retcode, process.args,
#     578                                  output=stdout, stderr=stderr)
#     579 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['C:\\Users\\tg\\AppData\\Local\\Programs\\Azure Dev CLI\\azd.EXE', 'auth', 'token', '--output', 'json', '--scope', 'https://storage.azure.com/.default', '--tenant-id', '72f988bf-86f1-41af-91ab-2d7cd011db47']' returned non-zero exit status 1.
#
# The above exception was the direct cause of the following exception:
#
# ClientAuthenticationError                 Traceback (most recent call last)
# Cell In[6], line 13
#      11 # Datei hochladen
#      12 with open(file_path_on_disk, "rb") as data:
# ---> 13     blob_client.upload_blob(data, overwrite=True)
#      14     print(f"Hochgeladen: {relative_path}")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\core\tracing\decorator.py:119, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     117 # If tracing is disabled globally and user didn't explicitly enable it, don't trace.
#     118 if user_enabled is False or (not tracing_enabled and user_enabled is None):
# --> 119     return func(*args, **kwargs)
#     121 # Merge span is parameter is set, but only if no explicit parent are passed
#     122 if merge_span and not passed_in_parent:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\storage\blob\_blob_client.py:605, in BlobClient.upload_blob(self, data, blob_type, length, metadata, **kwargs)
#     589 options = _upload_blob_options(
#     590     data=data,
#     591     blob_type=blob_type,
#    (...)    602     client=self._client,
#     603     **kwargs)
#     604 if blob_type == BlobType.BlockBlob:
# --> 605     return upload_block_blob(**options)
#     606 if blob_type == BlobType.PageBlob:
#     607     return upload_page_blob(**options)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\storage\blob\_upload_helpers.py:197, in upload_block_blob(client, stream, overwrite, encryption_options, blob_settings, headers, validate_content, max_concurrency, length, **kwargs)
#     195 except HttpResponseError as error:
#     196     try:
# --> 197         process_storage_error(error)
#     198     except ResourceModifiedError as mod_error:
#     199         if not overwrite:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\storage\blob\_shared\response_handlers.py:92, in process_storage_error(storage_error)
#      89     storage_error.message = storage_error.message + \
#      90         '. This is likely due to an invalid shared key. Please check your shared key and try again.'
#      91 if not storage_error.response or storage_error.response.status_code in [200, 204]:
# ---> 92     raise storage_error
#      93 # If it is one of those three then it has been serialized prior by the generated layer.
#      94 if isinstance(storage_error, (PartialBatchErrorException,
#      95                               ClientAuthenticationError, ResourceNotFoundError, ResourceExistsError)):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\storage\blob\_upload_helpers.py:105, in upload_block_blob(client, stream, overwrite, encryption_options, blob_settings, headers, validate_content, max_concurrency, length, **kwargs)
#     102     encryption_data, data = encrypt_blob(data, encryption_options['key'], encryption_options['version'])
#     103     headers['x-ms-meta-encryptiondata'] = encryption_data
# --> 105 response = client.upload(
#     106     body=data,  # type: ignore [arg-type]
#     107     content_length=adjusted_count,
#     108     blob_http_headers=blob_headers,
#     109     headers=headers,
#     110     cls=return_response_headers,
#     111     validate_content=validate_content,
#     112     data_stream_total=adjusted_count,
#     113     upload_stream_current=0,
#     114     tier=tier.value if tier else None,
#     115     blob_tags_string=blob_tags_string,
#     116     immutability_policy_expiry=immutability_policy_expiry,
#     117     immutability_policy_mode=immutability_policy_mode,
#     118     legal_hold=legal_hold,
#     119     **kwargs)
#     121 if progress_hook:
#     122     progress_hook(adjusted_count, adjusted_count)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\core\tracing\decorator.py:119, in distributed_trace.<locals>.decorator.<locals>.wrapper_use_tracer(*args, **kwargs)
#     117 # If tracing is disabled globally and user didn't explicitly enable it, don't trace.
#     118 if user_enabled is False or (not tracing_enabled and user_enabled is None):
# --> 119     return func(*args, **kwargs)
#     121 # Merge span is parameter is set, but only if no explicit parent are passed
#     122 if merge_span and not passed_in_parent:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\storage\blob\_generated\operations\_block_blob_operations.py:878, in BlockBlobOperations.upload(self, content_length, body, timeout, transactional_content_md5, metadata, tier, request_id_parameter, blob_tags_string, immutability_policy_expiry, immutability_policy_mode, legal_hold, transactional_content_crc64, structured_body_type, structured_content_length, blob_http_headers, lease_access_conditions, cpk_info, cpk_scope_info, modified_access_conditions, **kwargs)
#     875 _request.url = self._client.format_url(_request.url)
#     877 _stream = False
# --> 878 pipeline_response: PipelineResponse = self._client._pipeline.run(  # pylint: disable=protected-access
#     879     _request, stream=_stream, **kwargs
#     880 )
#     882 response = pipeline_response.http_response
#     884 if response.status_code not in [201]:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\core\pipeline\_base.py:242, in Pipeline.run(self, request, **kwargs)
#     240 pipeline_request: PipelineRequest[HTTPRequestType] = PipelineRequest(request, context)
#     241 first_node = self._impl_policies[0] if self._impl_policies else _TransportRunner(self._transport)
# --> 242 return first_node.send(pipeline_request)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
#     [... skipping similar frames: _SansIOHTTPPolicyRunner.send at line 98 (2 times)]
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\core\pipeline\policies\_redirect.py:205, in RedirectPolicy.send(self, request)
#     203 original_domain = get_domain(request.http_request.url) if redirect_settings["allow"] else None
#     204 while retryable:
# --> 205     response = self.next.send(request)
#     206     redirect_location = self.get_redirect_location(response)
#     207     if redirect_location and redirect_settings["allow"]:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\storage\blob\_shared\policies.py:555, in StorageRetryPolicy.send(self, request)
#     553             self.sleep(retry_settings, request.context.transport)
#     554             continue
# --> 555         raise err
#     556 if retry_settings['history']:
#     557     response.context['history'] = retry_settings['history']
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\storage\blob\_shared\policies.py:527, in StorageRetryPolicy.send(self, request)
#     525 while retries_remaining:
#     526     try:
# --> 527         response = self.next.send(request)
#     528         if is_retry(response, retry_settings['mode']) or is_checksum_retry(response):
#     529             retries_remaining = self.increment(
#     530                 retry_settings,
#     531                 request=request.http_request,
#     532                 response=response.http_response)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\core\pipeline\_base.py:98, in _SansIOHTTPPolicyRunner.send(self, request)
#      96 _await_result(self._policy.on_request, request)
#      97 try:
# ---> 98     response = self.next.send(request)
#      99 except Exception:
#     100     _await_result(self._policy.on_exception, request)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:168, in BearerTokenCredentialPolicy.send(self, request)
#     166 self._token = None  # any cached token is invalid
#     167 if "WWW-Authenticate" in response.http_response.headers:
# --> 168     request_authorized = self.on_challenge(request, response)
#     169     if request_authorized:
#     170         # if we receive a challenge response, we retrieve a new token
#     171         # which matches the new target. In this case, we don't want to remove
#     172         # token from the request so clear the 'insecure_domain_change' tag
#     173         request.context.options.pop("insecure_domain_change", False)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\storage\blob\_shared\policies.py:692, in StorageBearerTokenCredentialPolicy.on_challenge(self, request, response)
#     689     return False
#     691 scope = challenge.resource_id + DEFAULT_OAUTH_SCOPE
# --> 692 self.authorize_request(request, scope, tenant_id=challenge.tenant_id)
#     694 return True
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:145, in BearerTokenCredentialPolicy.authorize_request(self, request, *scopes, **kwargs)
#     136 def authorize_request(self, request: PipelineRequest[HTTPRequestType], *scopes: str, **kwargs: Any) -> None:
#     137     """Acquire a token from the credential and authorize the request with it.
#     138
#     139     Keyword arguments are passed to the credential's get_token method. The token will be cached and used to
#    (...)    143     :param str scopes: required scopes of authentication
#     144     """
# --> 145     self._request_token(*scopes, **kwargs)
#     146     bearer_token = cast(Union["AccessToken", "AccessTokenInfo"], self._token).token
#     147     self._update_headers(request.http_request.headers, bearer_token)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:108, in _BearerTokenCredentialPolicyBase._request_token(self, *scopes, **kwargs)
#     101 def _request_token(self, *scopes: str, **kwargs: Any) -> None:
#     102     """Request a new token from the credential.
#     103
#     104     This will call the credential's appropriate method to get a token and store it in the policy.
#     105
#     106     :param str scopes: The type of access needed.
#     107     """
# --> 108     self._token = self._get_token(*scopes, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\core\pipeline\policies\_authentication.py:98, in _BearerTokenCredentialPolicyBase._get_token(self, *scopes, **kwargs)
#      95         if key in TokenRequestOptions.__annotations__:  # pylint: disable=no-member
#      96             options[key] = kwargs.pop(key)  # type: ignore[literal-required]
# ---> 98     return cast(SupportsTokenInfo, self._credential).get_token_info(*scopes, options=options)
#      99 return cast(TokenCredential, self._credential).get_token(*scopes, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\identity\_credentials\default.py:249, in DefaultAzureCredential.get_token_info(self, options, *scopes)
#     232 """Request an access token for `scopes`.
#     233
#     234 This is an alternative to `get_token` to enable certain scenarios that require additional properties
#    (...)    246    `message` attribute listing each authentication attempt and its error message.
#     247 """
#     248 if self._successful_credential:
# --> 249     token_info = cast(SupportsTokenInfo, self._successful_credential).get_token_info(*scopes, options=options)
#     250     _LOGGER.info(
#     251         "%s acquired a token from %s", self.__class__.__name__, self._successful_credential.__class__.__name__
#     252     )
#     253     return token_info
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\identity\_internal\decorators.py:23, in log_get_token.<locals>.wrapper(*args, **kwargs)
#      20 @functools.wraps(fn)
#      21 def wrapper(*args, **kwargs):
#      22     try:
# ---> 23         token = fn(*args, **kwargs)
#      24         _LOGGER.log(
#      25             logging.DEBUG if within_credential_chain.get() else logging.INFO,
#      26             "%s succeeded",
#      27             fn.__qualname__,
#      28         )
#      29         if _LOGGER.isEnabledFor(logging.DEBUG):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\identity\_credentials\azd_cli.py:153, in AzureDeveloperCliCredential.get_token_info(self, options, *scopes)
#     132 @log_get_token
#     133 def get_token_info(self, *scopes: str, options: Optional[TokenRequestOptions] = None) -> AccessTokenInfo:
#     134     """Request an access token for `scopes`.
#     135
#     136     This is an alternative to `get_token` to enable certain scenarios that require additional properties
#    (...)    151       the Azure Developer CLI but didn't receive an access token.
#     152     """
# --> 153     return self._get_token_base(*scopes, options=options)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\identity\_credentials\azd_cli.py:178, in AzureDeveloperCliCredential._get_token_base(self, options, *scopes, **kwargs)
#     176 if tenant:
#     177     command_args += ["--tenant-id", tenant]
# --> 178 output = _run_command(command_args, self._process_timeout)
#     180 token = parse_token(output)
#     181 if not token:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\azure\identity\_credentials\azd_cli.py:282, in _run_command(command_args, timeout)
#     280     if within_dac.get():
#     281         raise CredentialUnavailableError(message=message) from ex
# --> 282     raise ClientAuthenticationError(message=message) from ex
#     283 except OSError as ex:
#     284     # failed to execute 'cmd' or '/bin/sh'
#     285     error = CredentialUnavailableError(message="Failed to execute '{}'".format(args[0]))
#
# ClientAuthenticationError: {"type":"consoleMessage","timestamp":"2025-04-28T17:21:44.4649893+02:00","data":{"message":"\nERROR: fetching token: AADSTS50020: User account '{EUII Hidden}' from identity provider 'https://sts.windows.net/ff9527af-b2c8-4690-8d43-bb9d700dc274/' does not exist in tenant 'Microsoft' and cannot access the application '04b07795-8ddb-461a-bbee-02f9e1bf7b46'(Microsoft Azure CLI) in that tenant. The account needs to be added as an external user in the tenant first. Sign out and sign in again with a different Azure Active Directory user account. Trace ID: da609b0d-ba24-4e93-b8f5-f52b0cb75b00 Correlation ID: f030ce94-7231-42e4-88a1-6cac30d50234 Timestamp: 2025-04-28 15:21:43Z\n"}}
# {"type":"consoleMessage","timestamp":"2025-04-28T17:21:44.5051876+02:00","data":{"message":"Suggestion: reauthentication required, run `azd auth login --scope https://storage.azure.com/.default` to acquire a new token.\n"}}
